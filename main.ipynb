# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from src.analysis import getTimes

# %%
def plotTimes(time):
    sns.histplot(time, stat='probability')
    plt.yscale('log')
    plt.xlabel('time (s)')
    print('mean: ', time.mean())
    print('std: ', time.std())

# %%
t50 = getTimes('4mm_50')
plotTimes(t50)
# Out:
# mean:  0.6704439999999999
# std:  0.5736432075052851

# %%
t100 = getTimes('4mm_100')
plotTimes(t100)
plt.xlim((0,2))
# Out:
# mean:  0.3361465
# std:  0.32739598630853034
# (0.0, 2.0)

# %%
t150 = getTimes('4mm_150')
plotTimes(t150)
plt.xlim((0,2))
# Out:
# mean:  0.21437309999999998
# std:  0.12121742639916147
# (0.0, 2.0)

# %%
t200 = getTimes('4mm_200')
plotTimes(t200)
plt.xlim((0,1))
# Out:
# mean:  0.15875680000000003
# std:  0.06841221621094204
# (0.0, 1.0)

# %%
t75 = getTimes('4mm_75')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 t75 = getTimes('4mm_75')
# ----> 2 plotTimes(t75)
#
# Cell In[3], line 2, in plotTimes(time)
#       1 def plotTimes(time):
# ----> 2     sns.histplot(time, stat='probability')
#       3     plt.yscale('log')
#       4     plt.xlabel('time (s)')
#
# NameError: name 'sns' is not defined

# %%
plotTimes(t75)
# Out:
# mean:  0.4504432
# std:  0.4314839675065358

# %%
t200 = getTimes('4mm_125')
plotTimes(t200)
plt.xlim((0,1))
# Out:
# mean:  0.2501017
# std:  0.12167531649999583
# (0.0, 1.0)
